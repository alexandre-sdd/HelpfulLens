# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basic ingestion

# %%
root = Path().resolve().parent
data_path = root / "data"
raw_data_path = data_path / "raw"
Path.mkdir(raw_data_path / "parquet", exist_ok=True)

# %%
# df_business = pd.read_json(raw_data_path / "yelp_academic_dataset_business.json", lines=True)
# df_review = pd.read_json(raw_data_path / "yelp_academic_dataset_review.json", lines=True)
# df_user = pd.read_json(raw_data_path / "yelp_academic_dataset_user.json", lines=True)
# df_tip = pd.read_json(raw_data_path / "yelp_academic_dataset_tip.json", lines=True)
# df_checkin = pd.read_json(raw_data_path / "yelp_academic_dataset_checkin.json", lines=True)

# %%
df_business = pd.read_json(raw_data_path / "yelp_academic_dataset_business.json", lines=True)
df_business.to_parquet(raw_data_path / "parquet" / "business_raw.parquet", index=False)

# %%
df_review = pd.read_json(raw_data_path / "yelp_academic_dataset_review.json", lines=True)
df_review.to_parquet(raw_data_path / "parquet" /"review_raw.parquet", index=False)

# %%
df_user = pd.read_json(raw_data_path / "yelp_academic_dataset_user.json", lines=True)
df_user.to_parquet(raw_data_path / "parquet" / "user_raw.parquet", index=False)

# %% [markdown]
# ## Data Cleaning

# %%
df_review
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# ...

# %%
from src.utils.data_utils import get_project_root

PROJECT_ROOT = get_project_root()
DATA_DIR = PROJECT_ROOT / "data"
RAW_PARQUET_DIR = DATA_DIR / "raw" / "parquet"
CLEANED_DIR = DATA_DIR / "cleaned"
CLEANED_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from src.utils.data_utils import get_project_root
#       3 PROJECT_ROOT = get_project_root()
#       4 DATA_DIR = PROJECT_ROOT / "data"
#
# ModuleNotFoundError: No module named 'src'
